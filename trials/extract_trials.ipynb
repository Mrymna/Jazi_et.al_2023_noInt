# %% [markdown]
# # Extract autopi trials
#
# We need to get behavioral data into a format that we can correlate to the ephys data.
#
# We will extract trials, journeys and NavPaths.
#
# The NavPaths are small segments of behavior (e.g., search from arena entry to lever, search to lever press, etc.).
#
# We get the instantaneous behavioral variables (distance run, time in the navPath, speed, etc) for each time point of the navPaths.
#
# The main difference with the behavior_2021 project is that the position data comes from positrack (LED tracking) rather than from DLC.
#
# We had to write a new TrialElectro and JourneyElectro class in the autopipy package for this.
#
# Here is a list of files that are important for this process
#
# We adjusted how the lever distance was calculated. The calculations of the NavPath objects (which is the distance from a single point) is overwritten in the Journey objects code (distance from the lever box).
#
#
# ## Main output files
#
# We save these files for later analysis in the data directory of each session.
#
# * `trialsWithJourneys.pdf`
# * `navPathSummary.csv` (about 900 lines)
# * `navPathInstan.csv` (about 150000 lines)
#
# We also save the myProject object as a pickle. This can be loaded later instead of always re-running the analysis.
#
# * `/repo/autopi_analysis/Jazi_et.al_2023/trials/myProjectWithTrials.pickle`

# %% [markdown]
# ## Note on position tracking
#
# We need to have very good tracking on the arena without too many missing values. We applied a gh filter to improve the situation for some sessions.

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.patches as patches

# %%
# %load_ext autoreload
# %autoreload 2

# %run ../setup_project.py
# %run ../neuronAutopi.py

prepareSessionsForSpatialAnalysisProject(sSesList,myProject.sessionList,pose_file_extension = ".pose_kf.npy") # use the output of the kalman filter
# Out:
# data path: /d80/Jazi_etal_2023_noInter
# Project name: autopi_ca1
# dataPath: /d80/Jazi_etal_2023_noInter/autopi_ca1
# Reading /d80/Jazi_etal_2023_noInter/autopi_ca1/sessionList
# We have 39 testing sessions in the list
# See myProject and sSesList objects
# Loading Animal_pose and Spike_train, sSes.ap and sSes.cg
# 100%|███████████████████████████████████████████| 39/39 [00:21<00:00,  1.80it/s]
# Loading ses.trial_table_simple as ses.trials
# Create condition intervals in ses.intervalDict

# %% [markdown]
# ## Creating a list of TrialElectro
#
# `TrialElectro` is a class in `autopipy` that is very similar to the `Trial` class that was developed for the behavioral experiment. The main difference is that it is adapted the spatial data coming from electrophysiology experiments. A TrialElectro object has a JourneyList which are JourneyElectro objects. The JourneyElectro objects have a dictionary of paths.

# %%
def extractNavPath(ses,sSes,verbose=False):
    
    loadTrials(ses,sSes)
    print("Trials: ", ses.nTrials, " Journeys:", ses.nJourneys)

    #This summary DataFrame can be used to select NavPaths that we want to analyze. The column "name" can be used to get the the instantaneous data for analysis with electrophysiological data.
    #It contains the time intervals to limit our spikeA.SpikeTrain to specific intervals. 
    #There are 2 functions in setup projects to transform ROS to res time (`RosToResTime()`and `resToRosTime()`).
    navPathSummary = ses.navPathIntervals()
    navPathSummary["startTimeRes"] = RosToResTime(navPathSummary.startTimeRos,np.stack([sSes.ap.pose[:,0],sSes.ap.pose[:,7]],axis=1))
    navPathSummary["endTimeRes"] = RosToResTime(navPathSummary.endTimeRos,np.stack([sSes.ap.pose[:,0],sSes.ap.pose[:,7]],axis=1))
    navPathSummary
    fn = ses.path+"/navPathSummary.csv"
    print("saving",fn)
    navPathSummary.to_csv(fn,index=False)


    # this is data with the instantaneous variables (variables evolving during navPath (distance to target, time, etc.)
    navPathInstan = ses.navPathInstantaneousBehavioralData()
    #navPathInstan["timeRes"] = RosToResTime(navPathInstan.timeRos,np.stack([sSes.ap.pose[:,0],sSes.ap.pose[:,7]],axis=1))
    navPathInstan
    fn = ses.path+"/navPathInstan.csv"
    print("saving",fn)
    navPathInstan.to_csv(fn,index=False)
    
    # save the session object
    fn=ses.path+"/ses.pickle"
    print("Saving:",fn)
    with open(fn, 'wb') as handle:
        pickle.dump(ses, handle)

# %%
def loadTrials(ses,sSes):
    ## create a list of autopipy.Trial objects
    ses.segmentTrialsFromLog()
    ses.createTrialElectroList() # create a List of TrialElectro object
    ses.loadLogFile()
    ses.extractTrialElectroFeatures(sSes.ap.pose,verbose=False) # this will give us a list of ElectroTrials
    print(ses.nTrials, ses.nJourneys)

# %% [markdown]
# ## Run the fun on single session

# %%
i=0
ses = myProject.sessionList[i]
sSes = sSesList[i]
ses.path                              

ses.segmentTrialsFromLog()
ses.createTrialElectroList() # create a List of TrialElectro object
ses.loadLogFile()
# Out:
# mn5824-20112020-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 152

# %%
myProject.dataPath
# Out:
# '/d80/Jazi_etal_2023_noInter/autopi_ca1'

# %%
# %%time
np.seterr(invalid='ignore')
ses.extractTrialElectroFeatures(sSes.ap.pose,verbose=False) # this will give us a list of ElectroTrials
# Out:
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-20112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time; no adjustTrialStart
# mn5824-20112020-0107_1, no mouse position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, the mouse was detected for fewer than 20 frames during the trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever press or no mouse position
# mn5824-20112020-0107_1, self.valid set to False
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# mn5824-20112020-0107_7, position of the animal at first lever press unknown
# mn5824-20112020-0107_7, self.valid set to False
# mn5824-20112020-0107_9, position of the animal at first lever press unknown
# mn5824-20112020-0107_9, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn5824-20112020-0107_51, start time adjustment: -18.4626 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# CPU times: user 36.6 s, sys: 134 ms, total: 36.7 s
# Wall time: 36.7 s

# %%
t = ses.trialList[1]
fig,ax = plt.subplots(1,6,figsize=(15,4))
t.plotTrialAndJourneys(ax)
j = t.journeyList[-1]
j.navPaths.keys()
# Out:
# dict_keys(['all', 'searchPath', 'searchToLeverPath', 'homingPath', 'homingFromLeavingLever', 'homingFromLeavingLeverToPeriphery', 'atLever'])

# %% [markdown]
# Angle of entry to the lever zone

# %% [markdown]
# ## Run on all sessions

# %% [markdown]
# ## loadTrials
#
# This saves `myProjectWithTrials.pkl`

# %%
# %%time
for i,(ses,sSes) in enumerate(zip(myProject.sessionList[:],sSesList[:])):
    print(i,ses.name,sSes.name)
    #loadTrials(ses,sSes)
    extractNavPath(ses,sSes)
# Out:
# 0 mn5824-20112020-0107 mn5824-20112020-0107
# mn5824-20112020-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 152
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-20112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time; no adjustTrialStart
# mn5824-20112020-0107_1, no mouse position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, the mouse was detected for fewer than 20 frames during the trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever press or no mouse position
# mn5824-20112020-0107_1, self.valid set to False
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# mn5824-20112020-0107_7, position of the animal at first lever press unknown
# mn5824-20112020-0107_7, self.valid set to False
# mn5824-20112020-0107_9, position of the animal at first lever press unknown
# mn5824-20112020-0107_9, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn5824-20112020-0107_51, start time adjustment: -18.4626 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 152 277
# Trials:  152  Journeys: 277
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-20112020-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-20112020-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-20112020-0107/ses.pickle
# 1 mn5824-22112020-0107 mn5824-22112020-0107
# mn5824-22112020-0107 trial segmentation
# Number of trials : 124
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-22112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# no bridge time before start; no adjustTrialStart
# mn5824-22112020-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn5824-22112020-0107_53, position of the animal at first lever press unknown
# mn5824-22112020-0107_53, self.valid set to False
# mn5824-22112020-0107_120, position of the animal at first lever press unknown
# mn5824-22112020-0107_120, self.valid set to False
# 124 228
# Trials:  124  Journeys: 228
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-22112020-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-22112020-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-22112020-0107/ses.pickle
# 2 mn5824-24112020-0107 mn5824-24112020-0107
# mn5824-24112020-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 135
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-24112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 114, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# no bridge time; no adjustTrialStart
# mn5824-24112020-0107_130, the mouse was detected for fewer than 20 frames during the trial
# mn5824-24112020-0107_130, self.valid set to False
# mn5824-24112020-0107_130, position of the animal at first lever press unknown
# mn5824-24112020-0107_130, self.valid set to False
# mn5824-24112020-0107_134, position of the animal at first lever press unknown
# mn5824-24112020-0107_134, self.valid set to False
# 135 233
# Trials:  135  Journeys: 233
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-24112020-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-24112020-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-24112020-0107/ses.pickle
# 3 mn5824-02122020-0106 mn5824-02122020-0106
# mn5824-02122020-0106 trial segmentation
# problem with the door alternation
# Problem with index 5497
# Removing the second of two door closings (index :5497)
# Number of trials : 156
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-02122020-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 156 227
# Trials:  156  Journeys: 227
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-02122020-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-02122020-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn5824/mn5824-02122020-0106/ses.pickle
# 4 mn711-28012021-0106 mn711-28012021-0106
# mn711-28012021-0106 trial segmentation
# Number of trials : 88
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-28012021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time before start; no adjustTrialStart
# mn711-28012021-0106_1, add a journey missed because of no brige time before first arenaCenter
# 88 116
# Trials:  88  Journeys: 116
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-28012021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-28012021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-28012021-0106/ses.pickle
# 5 mn711-30012021-0106 mn711-30012021-0106
# mn711-30012021-0106 trial segmentation
# Remove last opening of the door
# problem with the door alternation
# Problem with index 1355
# Removing the second of two door closings (index :1355)
# Problem with index 2003
# Removing the second of two door closings (index :2003)
# Problem with index 2228
# Removing the second of two door closings (index :2228)
# Number of trials : 81
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-30012021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# no bridge time before start; no adjustTrialStart
# mn711-30012021-0106_1, add a journey missed because of no brige time before first arenaCenter
# mn711-30012021-0106_8, position of the animal at first lever press unknown
# mn711-30012021-0106_8, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 9, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 81, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 81 125
# Trials:  81  Journeys: 125
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-30012021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-30012021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-30012021-0106/ses.pickle
# 6 mn711-31012021-0107 mn711-31012021-0107
# mn711-31012021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 80
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-31012021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 80 119
# Trials:  80  Journeys: 119
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-31012021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-31012021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-31012021-0107/ses.pickle
# 7 mn711-01022021-0107 mn711-01022021-0107
# mn711-01022021-0107 trial segmentation
# Number of trials : 87
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-01022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# no bridge time before start; no adjustTrialStart
# mn711-01022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 32, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn711-01022021-0107_64, position of the animal at first lever press unknown
# mn711-01022021-0107_64, self.valid set to False
# 87 152
# Trials:  87  Journeys: 152
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-01022021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-01022021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-01022021-0107/ses.pickle
# 8 mn711-02022021-0108 mn711-02022021-0108
# mn711-02022021-0108 trial segmentation
# Remove last opening of the door
# Number of trials : 101
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-02022021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# mn711-02022021-0108_24, start time adjustment: -8.8131 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn711-02022021-0108_24, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 101 135
# Trials:  101  Journeys: 135
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-02022021-0108/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-02022021-0108/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-02022021-0108/ses.pickle
# 9 mn711-03022021-0107 mn711-03022021-0107
# mn711-03022021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 76
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-03022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# 76 120
# Trials:  76  Journeys: 120
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-03022021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-03022021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-03022021-0107/ses.pickle
# 10 mn711-04022021-0107 mn711-04022021-0107
# mn711-04022021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 69
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-04022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# no bridge time before start; no adjustTrialStart
# mn711-04022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn711-04022021-0107_58, position of the animal at first lever press unknown
# mn711-04022021-0107_58, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# 69 117
# Trials:  69  Journeys: 117
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-04022021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-04022021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn711/mn711-04022021-0107/ses.pickle
# 11 mn2739-11022021-0107 mn2739-11022021-0107
# mn2739-11022021-0107 trial segmentation
# Number of trials : 158
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-11022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn2739-11022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn2739-11022021-0107_110, start time adjustment: -8.4477 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-11022021-0107_110, add a journey missed because of no brige time before first arenaCenter
# mn2739-11022021-0107_158, position of the animal at first lever press unknown
# mn2739-11022021-0107_158, self.valid set to False
# 158 212
# Trials:  158  Journeys: 212
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-11022021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-11022021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-11022021-0107/ses.pickle
# 12 mn2739-15022021-0105 mn2739-15022021-0105
# mn2739-15022021-0105 trial segmentation
# Number of trials : 108
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-15022021-0105/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mn2739-15022021-0105_26, position of the animal at first lever press unknown
# mn2739-15022021-0105_26, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn2739-15022021-0105_54, start time adjustment: -18.4253 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-15022021-0105_54, add a journey missed because of no brige time before first arenaCenter
# 108 139
# Trials:  108  Journeys: 139
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-15022021-0105/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-15022021-0105/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-15022021-0105/ses.pickle
# 13 mn2739-16022021-0106 mn2739-16022021-0106
# mn2739-16022021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 139
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-16022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_133, no mouse position data during this trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, no lever position data during this trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, no lever press or no mouse position
# mn2739-16022021-0106_133, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_134, no mouse position data during this trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, no lever position data during this trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, no lever press or no mouse position
# mn2739-16022021-0106_134, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_135, no mouse position data during this trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, no lever position data during this trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, no lever press or no mouse position
# mn2739-16022021-0106_135, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_136, no mouse position data during this trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, no lever position data during this trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, no lever press or no mouse position
# mn2739-16022021-0106_136, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_137, no mouse position data during this trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, no lever position data during this trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, no lever press or no mouse position
# mn2739-16022021-0106_137, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_138, no mouse position data during this trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, no lever position data during this trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, no lever press or no mouse position
# mn2739-16022021-0106_138, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_139, no mouse position data during this trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, no lever position data during this trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, no lever press or no mouse position
# mn2739-16022021-0106_139, self.valid set to False
# 139 166
# Trials:  139  Journeys: 166
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-16022021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-16022021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-16022021-0106/ses.pickle
# 14 mn2739-17022021-0106 mn2739-17022021-0106
# mn2739-17022021-0106 trial segmentation
# Number of trials : 134
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-17022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# mn2739-17022021-0106_8, position of the animal at first lever press unknown
# mn2739-17022021-0106_8, self.valid set to False
# mn2739-17022021-0106_58, start time adjustment: -16.3233 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-17022021-0106_58, add a journey missed because of no brige time before first arenaCenter
# mn2739-17022021-0106_82, position of the animal at first lever press unknown
# mn2739-17022021-0106_82, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 134 176
# Trials:  134  Journeys: 176
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-17022021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-17022021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-17022021-0106/ses.pickle
# 15 mn2739-21022021-0106 mn2739-21022021-0106
# mn2739-21022021-0106 trial segmentation
# Number of trials : 157
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-21022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# no bridge time before start; no adjustTrialStart
# mn2739-21022021-0106_1, add a journey missed because of no brige time before first arenaCenter
# mn2739-21022021-0106_52, start time adjustment: -8.5728 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-21022021-0106_52, add a journey missed because of no brige time before first arenaCenter
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn2739-21022021-0106_107, start time adjustment: -18.7943 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-21022021-0106_107, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 141, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 157 190
# Trials:  157  Journeys: 190
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-21022021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-21022021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn2739/mn2739-21022021-0106/ses.pickle
# 16 mn3246-09042021-0106 mn3246-09042021-0106
# mn3246-09042021-0106 trial segmentation
# Number of trials : 124
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-09042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# no bridge time before start; no adjustTrialStart
# mn3246-09042021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# mn3246-09042021-0106_14, position of the animal at first lever press unknown
# mn3246-09042021-0106_14, self.valid set to False
# mn3246-09042021-0106_22, position of the animal at first lever press unknown
# mn3246-09042021-0106_22, self.valid set to False
# mn3246-09042021-0106_36, position of the animal at first lever press unknown
# mn3246-09042021-0106_36, self.valid set to False
# mn3246-09042021-0106_98, position of the animal at first lever press unknown
# mn3246-09042021-0106_98, self.valid set to False
# 124 170
# Trials:  124  Journeys: 170
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-09042021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-09042021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-09042021-0106/ses.pickle
# 17 mn3246-10042021-0106 mn3246-10042021-0106
# mn3246-10042021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3958
# Removing the second of two door closings (index :3958)
# Number of trials : 119
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-10042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# mn3246-10042021-0106_36, position of the animal at first lever press unknown
# mn3246-10042021-0106_36, self.valid set to False
# mn3246-10042021-0106_38, position of the animal at first lever press unknown
# mn3246-10042021-0106_38, self.valid set to False
# mn3246-10042021-0106_41, position of the animal at first lever press unknown
# mn3246-10042021-0106_41, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# mn3246-10042021-0106_42, position of the animal at first lever press unknown
# mn3246-10042021-0106_42, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-10042021-0106_58, position of the animal at first lever press unknown
# mn3246-10042021-0106_58, self.valid set to False
# mn3246-10042021-0106_60, position of the animal at first lever press unknown
# mn3246-10042021-0106_60, self.valid set to False
# mn3246-10042021-0106_62, position of the animal at first lever press unknown
# mn3246-10042021-0106_62, self.valid set to False
# 119 162
# Trials:  119  Journeys: 162
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-10042021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-10042021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-10042021-0106/ses.pickle
# 18 mn3246-12042021-0106 mn3246-12042021-0106
# mn3246-12042021-0106 trial segmentation
# problem with the door alternation
# Problem with index 4356
# Removing the second of two door closings (index :4356)
# Number of trials : 139
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-12042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time before start; no adjustTrialStart
# mn3246-12042021-0106_22, position of the animal at first lever press unknown
# mn3246-12042021-0106_22, self.valid set to False
# mn3246-12042021-0106_24, position of the animal at first lever press unknown
# mn3246-12042021-0106_24, self.valid set to False
# mn3246-12042021-0106_49, position of the animal at first lever press unknown
# mn3246-12042021-0106_49, self.valid set to False
# mn3246-12042021-0106_53, position of the animal at first lever press unknown
# mn3246-12042021-0106_53, self.valid set to False
# mn3246-12042021-0106_63, position of the animal at first lever press unknown
# mn3246-12042021-0106_63, self.valid set to False
# mn3246-12042021-0106_67, position of the animal at first lever press unknown
# mn3246-12042021-0106_67, self.valid set to False
# mn3246-12042021-0106_68, position of the animal at first lever press unknown
# mn3246-12042021-0106_68, self.valid set to False
# mn3246-12042021-0106_82, position of the animal at first lever press unknown
# mn3246-12042021-0106_82, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-12042021-0106_96, position of the animal at first lever press unknown
# mn3246-12042021-0106_96, self.valid set to False
# mn3246-12042021-0106_101, position of the animal at first lever press unknown
# mn3246-12042021-0106_101, self.valid set to False
# mn3246-12042021-0106_104, position of the animal at first lever press unknown
# mn3246-12042021-0106_104, self.valid set to False
# mn3246-12042021-0106_106, position of the animal at first lever press unknown
# mn3246-12042021-0106_106, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 121, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 122, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 122, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 139 179
# Trials:  139  Journeys: 179
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-12042021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-12042021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-12042021-0106/ses.pickle
# 19 mn3246-14042021-0106 mn3246-14042021-0106
# mn3246-14042021-0106 trial segmentation
# Number of trials : 101
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-14042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# mn3246-14042021-0106_9, position of the animal at first lever press unknown
# mn3246-14042021-0106_9, self.valid set to False
# mn3246-14042021-0106_11, position of the animal at first lever press unknown
# mn3246-14042021-0106_11, self.valid set to False
# mn3246-14042021-0106_12, position of the animal at first lever press unknown
# mn3246-14042021-0106_12, self.valid set to False
# mn3246-14042021-0106_15, position of the animal at first lever press unknown
# mn3246-14042021-0106_15, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 27, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_32, position of the animal at first lever press unknown
# mn3246-14042021-0106_32, self.valid set to False
# mn3246-14042021-0106_33, position of the animal at first lever press unknown
# mn3246-14042021-0106_33, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_41, position of the animal at first lever press unknown
# mn3246-14042021-0106_41, self.valid set to False
# mn3246-14042021-0106_43, position of the animal at first lever press unknown
# mn3246-14042021-0106_43, self.valid set to False
# mn3246-14042021-0106_44, position of the animal at first lever press unknown
# mn3246-14042021-0106_44, self.valid set to False
# mn3246-14042021-0106_45, start time adjustment: -40.9504 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_68, position of the animal at first lever press unknown
# mn3246-14042021-0106_68, self.valid set to False
# mn3246-14042021-0106_69, position of the animal at first lever press unknown
# mn3246-14042021-0106_69, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 79, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_85, start time adjustment: -52.0854 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_85, add a journey missed because of no brige time before first arenaCenter
# mn3246-14042021-0106_96, position of the animal at first lever press unknown
# mn3246-14042021-0106_96, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_101, start time adjustment: -39.7959 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_101, no lever press or no mouse position
# mn3246-14042021-0106_101, self.valid set to False
# 101 141
# Trials:  101  Journeys: 141
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-14042021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-14042021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn3246/mn3246-14042021-0106/ses.pickle
# 20 mn1173-02052021-0107 mn1173-02052021-0107
# mn1173-02052021-0107 trial segmentation
# Number of trials : 110
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-02052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mn1173-02052021-0107_30, position of the animal at first lever press unknown
# mn1173-02052021-0107_30, self.valid set to False
# mn1173-02052021-0107_31, position of the animal at first lever press unknown
# mn1173-02052021-0107_31, self.valid set to False
# mn1173-02052021-0107_41, position of the animal at first lever press unknown
# mn1173-02052021-0107_41, self.valid set to False
# mn1173-02052021-0107_54, position of the animal at first lever press unknown
# mn1173-02052021-0107_54, self.valid set to False
# mn1173-02052021-0107_63, position of the animal at first lever press unknown
# mn1173-02052021-0107_63, self.valid set to False
# mn1173-02052021-0107_86, position of the animal at first lever press unknown
# mn1173-02052021-0107_86, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-02052021-0107_110, no lever press or no mouse position
# mn1173-02052021-0107_110, self.valid set to False
# 110 173
# Trials:  110  Journeys: 173
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-02052021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-02052021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-02052021-0107/ses.pickle
# 21 mn1173-06052021-0107 mn1173-06052021-0107
# mn1173-06052021-0107 trial segmentation
# Number of trials : 117
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-06052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn1173-06052021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-06052021-0107_20, position of the animal at first lever press unknown
# mn1173-06052021-0107_20, self.valid set to False
# mn1173-06052021-0107_60, position of the animal at first lever press unknown
# mn1173-06052021-0107_60, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-06052021-0107_83, start time adjustment: -13.2631 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-06052021-0107_83, add a journey missed because of no brige time before first arenaCenter
# 117 171
# Trials:  117  Journeys: 171
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-06052021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-06052021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-06052021-0107/ses.pickle
# 22 mn1173-08052021-0107 mn1173-08052021-0107
# mn1173-08052021-0107 trial segmentation
# Number of trials : 119
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-08052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn1173-08052021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-08052021-0107_12, position of the animal at first lever press unknown
# mn1173-08052021-0107_12, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_33, position of the animal at first lever press unknown
# mn1173-08052021-0107_33, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_44, position of the animal at first lever press unknown
# mn1173-08052021-0107_44, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_64, position of the animal at first lever press unknown
# mn1173-08052021-0107_64, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_112, start time adjustment: -8.9722 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-08052021-0107_112, position of the animal at first lever press unknown
# mn1173-08052021-0107_112, self.valid set to False
# mn1173-08052021-0107_112, add a journey missed because of no brige time before first arenaCenter
# mn1173-08052021-0107_119, no lever press or no mouse position
# mn1173-08052021-0107_119, self.valid set to False
# 119 166
# Trials:  119  Journeys: 166
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-08052021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-08052021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-08052021-0107/ses.pickle
# 23 mn1173-09052021-0108 mn1173-09052021-0108
# mn1173-09052021-0108 trial segmentation
# Number of trials : 142
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-09052021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.25
# no bridge time before start; no adjustTrialStart
# mn1173-09052021-0108_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-09052021-0108_6, position of the animal at first lever press unknown
# mn1173-09052021-0108_6, self.valid set to False
# mn1173-09052021-0108_7, position of the animal at first lever press unknown
# mn1173-09052021-0108_7, self.valid set to False
# mn1173-09052021-0108_8, position of the animal at first lever press unknown
# mn1173-09052021-0108_8, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-09052021-0108_48, position of the animal at first lever press unknown
# mn1173-09052021-0108_48, self.valid set to False
# mn1173-09052021-0108_55, position of the animal at first lever press unknown
# mn1173-09052021-0108_55, self.valid set to False
# mn1173-09052021-0108_64, position of the animal at first lever press unknown
# mn1173-09052021-0108_64, self.valid set to False
# mn1173-09052021-0108_66, position of the animal at first lever press unknown
# mn1173-09052021-0108_66, self.valid set to False
# mn1173-09052021-0108_68, position of the animal at first lever press unknown
# mn1173-09052021-0108_68, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-09052021-0108_72, position of the animal at first lever press unknown
# mn1173-09052021-0108_72, self.valid set to False
# mn1173-09052021-0108_76, position of the animal at first lever press unknown
# mn1173-09052021-0108_76, self.valid set to False
# mn1173-09052021-0108_126, position of the animal at first lever press unknown
# mn1173-09052021-0108_126, self.valid set to False
# 142 192
# Trials:  142  Journeys: 192
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-09052021-0108/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-09052021-0108/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-09052021-0108/ses.pickle
# 24 mn1173-11052021-0108 mn1173-11052021-0108
# mn1173-11052021-0108 trial segmentation
# problem with the door alternation
# Problem with index 4895
# Removing the second of two door closings (index :4895)
# Number of trials : 113
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-11052021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-11052021-0108_57, position of the animal at first lever press unknown
# mn1173-11052021-0108_57, self.valid set to False
# mn1173-11052021-0108_97, start time adjustment: -15.2468 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-11052021-0108_97, add a journey missed because of no brige time before first arenaCenter
# 113 132
# Trials:  113  Journeys: 132
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-11052021-0108/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-11052021-0108/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn1173/mn1173-11052021-0108/ses.pickle
# 25 TYY9524-16082021-0106 TYY9524-16082021-0106
# TYY9524-16082021-0106 trial segmentation
# Number of trials : 122
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY9524/TYY9524-16082021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# TYY9524-16082021-0106_3, position of the animal at first lever press unknown
# TYY9524-16082021-0106_3, self.valid set to False
# TYY9524-16082021-0106_7, position of the animal at first lever press unknown
# TYY9524-16082021-0106_7, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 8, journeyNo: 5, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY9524-16082021-0106_9, start time adjustment: -5.0639 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY9524-16082021-0106_9, add a journey missed because of no brige time before first arenaCenter
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# ...
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 108 229
# Trials:  108  Journeys: 229
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-17092021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-17092021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-17092021-0106/ses.pickle
# 31 TYY5622-19092021-0106 TYY5622-19092021-0106
# TYY5622-19092021-0106 trial segmentation
# problem with the door alternation
# Problem with index 2918
# Removing the second of two door closings (index :2918)
# Number of trials : 102
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-19092021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# TYY5622-19092021-0106_1, start time adjustment: -2666.8835 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY5622-19092021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 4, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY5622-19092021-0106_30, position of the animal at first lever press unknown
# TYY5622-19092021-0106_30, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 45, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 90, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 102 252
# Trials:  102  Journeys: 252
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-19092021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-19092021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-19092021-0106/ses.pickle
# 32 TYY5622-20092021-0106 TYY5622-20092021-0106
# TYY5622-20092021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 128
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-20092021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# TYY5622-20092021-0106_1, start time adjustment: -2890.2968 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY5622-20092021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY5622-20092021-0106_90, position of the animal at first lever press unknown
# TYY5622-20092021-0106_90, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 103, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 119, journeyNo: 6, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 128 238
# Trials:  128  Journeys: 238
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-20092021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-20092021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/TYY5622/TYY5622-20092021-0106/ses.pickle
# 33 mn9686-20102021-0106 mn9686-20102021-0106
# mn9686-20102021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3225
# Removing the second of two door closings (index :3225)
# Number of trials : 147
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-20102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 2, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 3, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_10, position of the animal at first lever press unknown
# mn9686-20102021-0106_10, self.valid set to False
# We have a navPath with empty pPose in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_48, position of the animal at first lever press unknown
# mn9686-20102021-0106_48, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 60, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 60, journeyNo: 6, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 60, journeyNo: 7, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_91, position of the animal at first lever press unknown
# mn9686-20102021-0106_91, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_144, position of the animal at first lever press unknown
# mn9686-20102021-0106_144, self.valid set to False
# 147 258
# Trials:  147  Journeys: 258
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-20102021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-20102021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-20102021-0106/ses.pickle
# 34 mn9686-26102021-0106 mn9686-26102021-0106
# mn9686-26102021-0106 trial segmentation
# Number of trials : 125
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-26102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 14, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-26102021-0106_73, start time adjustment: -40.0199 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-26102021-0106_73, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 74, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# mn9686-26102021-0106_82, start time adjustment: -9.0814 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-26102021-0106_82, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 107, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 125 255
# Trials:  125  Journeys: 255
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-26102021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-26102021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-26102021-0106/ses.pickle
# 35 mn9686-27102021-0106 mn9686-27102021-0106
# mn9686-27102021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 138
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-27102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# mn9686-27102021-0106_1, start time adjustment: -2145.0546 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-27102021-0106_1, add a journey missed because of no brige time before first arenaCenter
# We have a navPath with empty pPose in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 84, journeyNo: 5, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 84, journeyNo: 7, not time on the arena, we will only have a `all` navPath
# mn9686-27102021-0106_138, position of the animal at first lever press unknown
# mn9686-27102021-0106_138, self.valid set to False
# 138 252
# Trials:  138  Journeys: 252
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-27102021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-27102021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-27102021-0106/ses.pickle
# 36 mn9686-28102021-0107 mn9686-28102021-0107
# mn9686-28102021-0107 trial segmentation
# Number of trials : 146
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-28102021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# mn9686-28102021-0107_1, start time adjustment: -2372.0206 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-28102021-0107_1, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-28102021-0107_146, no lever press or no mouse position
# mn9686-28102021-0107_146, self.valid set to False
# 146 224
# Trials:  146  Journeys: 224
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-28102021-0107/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-28102021-0107/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-28102021-0107/ses.pickle
# 37 mn9686-29102021-0106 mn9686-29102021-0106
# mn9686-29102021-0106 trial segmentation
# problem with the door alternation
# Problem with index 2776
# Removing the second of two door closings (index :2776)
# Number of trials : 138
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-29102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 138 211
# Trials:  138  Journeys: 211
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-29102021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-29102021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-29102021-0106/ses.pickle
# 38 mn9686-01112021-0106 mn9686-01112021-0106
# mn9686-01112021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3167
# Removing the second of two door closings (index :3167)
# Number of trials : 160
# leverZoneMaxDistance calculation
# reading /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-01112021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# mn9686-01112021-0106_61, start time adjustment: -6.5549 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-01112021-0106_61, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 61, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 160 261
# Trials:  160  Journeys: 261
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-01112021-0106/navPathSummary.csv
# saving /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-01112021-0106/navPathInstan.csv
# Saving: /d80/Jazi_etal_2023_noInter/autopi_ca1/mn9686/mn9686-01112021-0106/ses.pickle
# CPU times: user 23min 33s, sys: 10.5 s, total: 23min 44s
# Wall time: 24min 7s

# %% [markdown]
# We can save the myProject (autopipy) session for later use. The size is approximately 5 Gb.

# %%
fn="/ext_drives/d80/Jazi_etal_2023/autopi_ca1/results/myProjectWithTrials.pickle"
print("Saving:",fn)
with open(fn, 'wb') as handle:
    pickle.dump(myProject, handle)
# Out:
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/results/myProjectWithTrials.pickle

# %% [markdown]
# ## function extractNavPath(ses,sSes) will generate the following files.
#
# * trialsWithJourneys.csv
# * navPathSummary.csv
# * navPathInstan.csv
#
# We will reload the myProjectWithTrials here so that you don't need to run the code above to run the code below

# %%
# %load_ext autoreload
# %autoreload 2
# %run  ~/repo/autopi_analysis_bk/Jazi_et.al_2023/setup_project.py
prepareSessionsForSpatialAnalysisProject(sSesList,myProject.sessionList,pose_file_extension = ".pose_kf.npy")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project name: autopi_ca1
# dataPath: /ext_drives/d80/Jazi_etal_2023/autopi_ca1
# dlcModelPath: /adata/models
# Reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/sessionList
# We have 39 testing sessions in the list
# See myProject and sSesList objects
# Loading Animal_pose and Spike_train, sSes.ap and sSes.cg
# 100%|███████████████████████████████████████████| 39/39 [00:22<00:00,  1.77it/s]
# Loading ses.trial_table_simple as ses.trials
# Create condition intervals in ses.intervalDict

# %%
# %%time
myProjectWithTrials = loadMyProjectWithTrials(myProject)
# Out:
# Loading: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/results/myProjectWithTrials.pickle
# CPU times: user 4.99 s, sys: 1.47 s, total: 6.45 s
# Wall time: 6.46 s

# %%
myProjectWithTrials.dataPath
# Out:
# '/ext_drives/d80/Jazi_etal_2023/autopi_ca1'

# %%
for i,(ses,sSes) in enumerate(zip(myProject.sessionList[:],sSesList[:])):
    print(i,ses.name,sSes.name)
    extractNavPath(ses,sSes)
# Out:
# 0 mn5824-20112020-0107 mn5824-20112020-0107
# mn5824-20112020-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 152
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-20112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time; no adjustTrialStart
# mn5824-20112020-0107_1, no mouse position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, the mouse was detected for fewer than 20 frames during the trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever position data during this trial
# mn5824-20112020-0107_1, self.valid set to False
# mn5824-20112020-0107_1, no lever press or no mouse position
# mn5824-20112020-0107_1, self.valid set to False
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# mn5824-20112020-0107_7, position of the animal at first lever press unknown
# mn5824-20112020-0107_7, self.valid set to False
# mn5824-20112020-0107_9, position of the animal at first lever press unknown
# mn5824-20112020-0107_9, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 34, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn5824-20112020-0107_51, start time adjustment: -18.4626 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 152 277
# Trials:  152  Journeys: 277
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-20112020-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-20112020-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-20112020-0107/ses.pickle
# 1 mn5824-22112020-0107 mn5824-22112020-0107
# mn5824-22112020-0107 trial segmentation
# Number of trials : 124
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-22112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# no bridge time before start; no adjustTrialStart
# mn5824-22112020-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn5824-22112020-0107_53, position of the animal at first lever press unknown
# mn5824-22112020-0107_53, self.valid set to False
# mn5824-22112020-0107_120, position of the animal at first lever press unknown
# mn5824-22112020-0107_120, self.valid set to False
# 124 228
# Trials:  124  Journeys: 228
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-22112020-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-22112020-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-22112020-0107/ses.pickle
# 2 mn5824-24112020-0107 mn5824-24112020-0107
# mn5824-24112020-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 135
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-24112020-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 114, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# no bridge time; no adjustTrialStart
# mn5824-24112020-0107_130, the mouse was detected for fewer than 20 frames during the trial
# mn5824-24112020-0107_130, self.valid set to False
# mn5824-24112020-0107_130, position of the animal at first lever press unknown
# mn5824-24112020-0107_130, self.valid set to False
# mn5824-24112020-0107_134, position of the animal at first lever press unknown
# mn5824-24112020-0107_134, self.valid set to False
# 135 233
# Trials:  135  Journeys: 233
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-24112020-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-24112020-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-24112020-0107/ses.pickle
# 3 mn5824-02122020-0106 mn5824-02122020-0106
# mn5824-02122020-0106 trial segmentation
# problem with the door alternation
# Problem with index 5497
# Removing the second of two door closings (index :5497)
# Number of trials : 156
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-02122020-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 156 227
# Trials:  156  Journeys: 227
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-02122020-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-02122020-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn5824/mn5824-02122020-0106/ses.pickle
# 4 mn711-28012021-0106 mn711-28012021-0106
# mn711-28012021-0106 trial segmentation
# Number of trials : 88
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-28012021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time before start; no adjustTrialStart
# mn711-28012021-0106_1, add a journey missed because of no brige time before first arenaCenter
# 88 116
# Trials:  88  Journeys: 116
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-28012021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-28012021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-28012021-0106/ses.pickle
# 5 mn711-30012021-0106 mn711-30012021-0106
# mn711-30012021-0106 trial segmentation
# Remove last opening of the door
# problem with the door alternation
# Problem with index 1355
# Removing the second of two door closings (index :1355)
# Problem with index 2003
# Removing the second of two door closings (index :2003)
# Problem with index 2228
# Removing the second of two door closings (index :2228)
# Number of trials : 81
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-30012021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# no bridge time before start; no adjustTrialStart
# mn711-30012021-0106_1, add a journey missed because of no brige time before first arenaCenter
# mn711-30012021-0106_8, position of the animal at first lever press unknown
# mn711-30012021-0106_8, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 9, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 81, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 81 125
# Trials:  81  Journeys: 125
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-30012021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-30012021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-30012021-0106/ses.pickle
# 6 mn711-31012021-0107 mn711-31012021-0107
# mn711-31012021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 80
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-31012021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 80 119
# Trials:  80  Journeys: 119
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-31012021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-31012021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-31012021-0107/ses.pickle
# 7 mn711-01022021-0107 mn711-01022021-0107
# mn711-01022021-0107 trial segmentation
# Number of trials : 87
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-01022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# no bridge time before start; no adjustTrialStart
# mn711-01022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 32, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn711-01022021-0107_64, position of the animal at first lever press unknown
# mn711-01022021-0107_64, self.valid set to False
# 87 152
# Trials:  87  Journeys: 152
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-01022021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-01022021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-01022021-0107/ses.pickle
# 8 mn711-02022021-0108 mn711-02022021-0108
# mn711-02022021-0108 trial segmentation
# Remove last opening of the door
# Number of trials : 101
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-02022021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# mn711-02022021-0108_24, start time adjustment: -8.8131 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn711-02022021-0108_24, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 101 135
# Trials:  101  Journeys: 135
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-02022021-0108/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-02022021-0108/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-02022021-0108/ses.pickle
# 9 mn711-03022021-0107 mn711-03022021-0107
# mn711-03022021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 76
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-03022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# 76 120
# Trials:  76  Journeys: 120
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-03022021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-03022021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-03022021-0107/ses.pickle
# 10 mn711-04022021-0107 mn711-04022021-0107
# mn711-04022021-0107 trial segmentation
# Remove last opening of the door
# Number of trials : 69
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-04022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# no bridge time before start; no adjustTrialStart
# mn711-04022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn711-04022021-0107_58, position of the animal at first lever press unknown
# mn711-04022021-0107_58, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# 69 117
# Trials:  69  Journeys: 117
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-04022021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-04022021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn711/mn711-04022021-0107/ses.pickle
# 11 mn2739-11022021-0107 mn2739-11022021-0107
# mn2739-11022021-0107 trial segmentation
# Number of trials : 158
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-11022021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn2739-11022021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn2739-11022021-0107_110, start time adjustment: -8.4477 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-11022021-0107_110, add a journey missed because of no brige time before first arenaCenter
# mn2739-11022021-0107_158, position of the animal at first lever press unknown
# mn2739-11022021-0107_158, self.valid set to False
# 158 212
# Trials:  158  Journeys: 212
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-11022021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-11022021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-11022021-0107/ses.pickle
# 12 mn2739-15022021-0105 mn2739-15022021-0105
# mn2739-15022021-0105 trial segmentation
# Number of trials : 108
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-15022021-0105/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mn2739-15022021-0105_26, position of the animal at first lever press unknown
# mn2739-15022021-0105_26, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn2739-15022021-0105_54, start time adjustment: -18.4253 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-15022021-0105_54, add a journey missed because of no brige time before first arenaCenter
# 108 139
# Trials:  108  Journeys: 139
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-15022021-0105/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-15022021-0105/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-15022021-0105/ses.pickle
# 13 mn2739-16022021-0106 mn2739-16022021-0106
# mn2739-16022021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 139
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-16022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_133, no mouse position data during this trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, no lever position data during this trial
# mn2739-16022021-0106_133, self.valid set to False
# mn2739-16022021-0106_133, no lever press or no mouse position
# mn2739-16022021-0106_133, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_134, no mouse position data during this trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, no lever position data during this trial
# mn2739-16022021-0106_134, self.valid set to False
# mn2739-16022021-0106_134, no lever press or no mouse position
# mn2739-16022021-0106_134, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_135, no mouse position data during this trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, no lever position data during this trial
# mn2739-16022021-0106_135, self.valid set to False
# mn2739-16022021-0106_135, no lever press or no mouse position
# mn2739-16022021-0106_135, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_136, no mouse position data during this trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, no lever position data during this trial
# mn2739-16022021-0106_136, self.valid set to False
# mn2739-16022021-0106_136, no lever press or no mouse position
# mn2739-16022021-0106_136, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_137, no mouse position data during this trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, no lever position data during this trial
# mn2739-16022021-0106_137, self.valid set to False
# mn2739-16022021-0106_137, no lever press or no mouse position
# mn2739-16022021-0106_137, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_138, no mouse position data during this trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, no lever position data during this trial
# mn2739-16022021-0106_138, self.valid set to False
# mn2739-16022021-0106_138, no lever press or no mouse position
# mn2739-16022021-0106_138, self.valid set to False
# no bridge time; no adjustTrialStart
# mn2739-16022021-0106_139, no mouse position data during this trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, the mouse was detected for fewer than 20 frames during the trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, no lever position data during this trial
# mn2739-16022021-0106_139, self.valid set to False
# mn2739-16022021-0106_139, no lever press or no mouse position
# mn2739-16022021-0106_139, self.valid set to False
# 139 166
# Trials:  139  Journeys: 166
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# /home/maryam/repo/autopipy/autopipy/trialElectro.py:432: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.positionZones["loca"] = self.positionZones.iloc[:, :].idxmax(1)
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-16022021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-16022021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-16022021-0106/ses.pickle
# 14 mn2739-17022021-0106 mn2739-17022021-0106
# mn2739-17022021-0106 trial segmentation
# Number of trials : 134
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-17022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# mn2739-17022021-0106_8, position of the animal at first lever press unknown
# mn2739-17022021-0106_8, self.valid set to False
# mn2739-17022021-0106_58, start time adjustment: -16.3233 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-17022021-0106_58, add a journey missed because of no brige time before first arenaCenter
# mn2739-17022021-0106_82, position of the animal at first lever press unknown
# mn2739-17022021-0106_82, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 134 176
# Trials:  134  Journeys: 176
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-17022021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-17022021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-17022021-0106/ses.pickle
# 15 mn2739-21022021-0106 mn2739-21022021-0106
# mn2739-21022021-0106 trial segmentation
# Number of trials : 157
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-21022021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# no bridge time before start; no adjustTrialStart
# mn2739-21022021-0106_1, add a journey missed because of no brige time before first arenaCenter
# mn2739-21022021-0106_52, start time adjustment: -8.5728 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-21022021-0106_52, add a journey missed because of no brige time before first arenaCenter
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn2739-21022021-0106_107, start time adjustment: -18.7943 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn2739-21022021-0106_107, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 141, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 157 190
# Trials:  157  Journeys: 190
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-21022021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-21022021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn2739/mn2739-21022021-0106/ses.pickle
# 16 mn3246-09042021-0106 mn3246-09042021-0106
# mn3246-09042021-0106 trial segmentation
# Number of trials : 124
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-09042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.75
# no bridge time before start; no adjustTrialStart
# mn3246-09042021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# mn3246-09042021-0106_14, position of the animal at first lever press unknown
# mn3246-09042021-0106_14, self.valid set to False
# mn3246-09042021-0106_22, position of the animal at first lever press unknown
# mn3246-09042021-0106_22, self.valid set to False
# mn3246-09042021-0106_36, position of the animal at first lever press unknown
# mn3246-09042021-0106_36, self.valid set to False
# mn3246-09042021-0106_98, position of the animal at first lever press unknown
# mn3246-09042021-0106_98, self.valid set to False
# 124 170
# Trials:  124  Journeys: 170
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-09042021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-09042021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-09042021-0106/ses.pickle
# 17 mn3246-10042021-0106 mn3246-10042021-0106
# mn3246-10042021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3958
# Removing the second of two door closings (index :3958)
# Number of trials : 119
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-10042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# mn3246-10042021-0106_36, position of the animal at first lever press unknown
# mn3246-10042021-0106_36, self.valid set to False
# mn3246-10042021-0106_38, position of the animal at first lever press unknown
# mn3246-10042021-0106_38, self.valid set to False
# mn3246-10042021-0106_41, position of the animal at first lever press unknown
# mn3246-10042021-0106_41, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# mn3246-10042021-0106_42, position of the animal at first lever press unknown
# mn3246-10042021-0106_42, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-10042021-0106_58, position of the animal at first lever press unknown
# mn3246-10042021-0106_58, self.valid set to False
# mn3246-10042021-0106_60, position of the animal at first lever press unknown
# mn3246-10042021-0106_60, self.valid set to False
# mn3246-10042021-0106_62, position of the animal at first lever press unknown
# mn3246-10042021-0106_62, self.valid set to False
# 119 162
# Trials:  119  Journeys: 162
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-10042021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-10042021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-10042021-0106/ses.pickle
# 18 mn3246-12042021-0106 mn3246-12042021-0106
# mn3246-12042021-0106 trial segmentation
# problem with the door alternation
# Problem with index 4356
# Removing the second of two door closings (index :4356)
# Number of trials : 139
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-12042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# no bridge time before start; no adjustTrialStart
# mn3246-12042021-0106_22, position of the animal at first lever press unknown
# mn3246-12042021-0106_22, self.valid set to False
# mn3246-12042021-0106_24, position of the animal at first lever press unknown
# mn3246-12042021-0106_24, self.valid set to False
# mn3246-12042021-0106_49, position of the animal at first lever press unknown
# mn3246-12042021-0106_49, self.valid set to False
# mn3246-12042021-0106_53, position of the animal at first lever press unknown
# mn3246-12042021-0106_53, self.valid set to False
# mn3246-12042021-0106_63, position of the animal at first lever press unknown
# mn3246-12042021-0106_63, self.valid set to False
# mn3246-12042021-0106_67, position of the animal at first lever press unknown
# mn3246-12042021-0106_67, self.valid set to False
# mn3246-12042021-0106_68, position of the animal at first lever press unknown
# mn3246-12042021-0106_68, self.valid set to False
# mn3246-12042021-0106_82, position of the animal at first lever press unknown
# mn3246-12042021-0106_82, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-12042021-0106_96, position of the animal at first lever press unknown
# mn3246-12042021-0106_96, self.valid set to False
# mn3246-12042021-0106_101, position of the animal at first lever press unknown
# mn3246-12042021-0106_101, self.valid set to False
# mn3246-12042021-0106_104, position of the animal at first lever press unknown
# mn3246-12042021-0106_104, self.valid set to False
# mn3246-12042021-0106_106, position of the animal at first lever press unknown
# mn3246-12042021-0106_106, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 121, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 122, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 122, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 139 179
# Trials:  139  Journeys: 179
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-12042021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-12042021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-12042021-0106/ses.pickle
# 19 mn3246-14042021-0106 mn3246-14042021-0106
# mn3246-14042021-0106 trial segmentation
# Number of trials : 101
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-14042021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# mn3246-14042021-0106_9, position of the animal at first lever press unknown
# mn3246-14042021-0106_9, self.valid set to False
# mn3246-14042021-0106_11, position of the animal at first lever press unknown
# mn3246-14042021-0106_11, self.valid set to False
# mn3246-14042021-0106_12, position of the animal at first lever press unknown
# mn3246-14042021-0106_12, self.valid set to False
# mn3246-14042021-0106_15, position of the animal at first lever press unknown
# mn3246-14042021-0106_15, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 27, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_32, position of the animal at first lever press unknown
# mn3246-14042021-0106_32, self.valid set to False
# mn3246-14042021-0106_33, position of the animal at first lever press unknown
# mn3246-14042021-0106_33, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_41, position of the animal at first lever press unknown
# mn3246-14042021-0106_41, self.valid set to False
# mn3246-14042021-0106_43, position of the animal at first lever press unknown
# mn3246-14042021-0106_43, self.valid set to False
# mn3246-14042021-0106_44, position of the animal at first lever press unknown
# mn3246-14042021-0106_44, self.valid set to False
# mn3246-14042021-0106_45, start time adjustment: -40.9504 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_68, position of the animal at first lever press unknown
# mn3246-14042021-0106_68, self.valid set to False
# mn3246-14042021-0106_69, position of the animal at first lever press unknown
# mn3246-14042021-0106_69, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 79, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_85, start time adjustment: -52.0854 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_85, add a journey missed because of no brige time before first arenaCenter
# mn3246-14042021-0106_96, position of the animal at first lever press unknown
# mn3246-14042021-0106_96, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn3246-14042021-0106_101, start time adjustment: -39.7959 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn3246-14042021-0106_101, no lever press or no mouse position
# mn3246-14042021-0106_101, self.valid set to False
# 101 141
# Trials:  101  Journeys: 141
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-14042021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-14042021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn3246/mn3246-14042021-0106/ses.pickle
# 20 mn1173-02052021-0107 mn1173-02052021-0107
# mn1173-02052021-0107 trial segmentation
# Number of trials : 110
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-02052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 7.25
# mn1173-02052021-0107_30, position of the animal at first lever press unknown
# mn1173-02052021-0107_30, self.valid set to False
# mn1173-02052021-0107_31, position of the animal at first lever press unknown
# mn1173-02052021-0107_31, self.valid set to False
# mn1173-02052021-0107_41, position of the animal at first lever press unknown
# mn1173-02052021-0107_41, self.valid set to False
# mn1173-02052021-0107_54, position of the animal at first lever press unknown
# mn1173-02052021-0107_54, self.valid set to False
# mn1173-02052021-0107_63, position of the animal at first lever press unknown
# mn1173-02052021-0107_63, self.valid set to False
# mn1173-02052021-0107_86, position of the animal at first lever press unknown
# mn1173-02052021-0107_86, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-02052021-0107_110, no lever press or no mouse position
# mn1173-02052021-0107_110, self.valid set to False
# 110 173
# Trials:  110  Journeys: 173
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-02052021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-02052021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-02052021-0107/ses.pickle
# 21 mn1173-06052021-0107 mn1173-06052021-0107
# mn1173-06052021-0107 trial segmentation
# Number of trials : 117
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-06052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn1173-06052021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-06052021-0107_20, position of the animal at first lever press unknown
# mn1173-06052021-0107_20, self.valid set to False
# mn1173-06052021-0107_60, position of the animal at first lever press unknown
# mn1173-06052021-0107_60, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-06052021-0107_83, start time adjustment: -13.2631 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-06052021-0107_83, add a journey missed because of no brige time before first arenaCenter
# 117 171
# Trials:  117  Journeys: 171
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-06052021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-06052021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-06052021-0107/ses.pickle
# 22 mn1173-08052021-0107 mn1173-08052021-0107
# mn1173-08052021-0107 trial segmentation
# Number of trials : 119
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-08052021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# no bridge time before start; no adjustTrialStart
# mn1173-08052021-0107_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-08052021-0107_12, position of the animal at first lever press unknown
# mn1173-08052021-0107_12, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_33, position of the animal at first lever press unknown
# mn1173-08052021-0107_33, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_44, position of the animal at first lever press unknown
# mn1173-08052021-0107_44, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_64, position of the animal at first lever press unknown
# mn1173-08052021-0107_64, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-08052021-0107_112, start time adjustment: -8.9722 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-08052021-0107_112, position of the animal at first lever press unknown
# mn1173-08052021-0107_112, self.valid set to False
# mn1173-08052021-0107_112, add a journey missed because of no brige time before first arenaCenter
# mn1173-08052021-0107_119, no lever press or no mouse position
# mn1173-08052021-0107_119, self.valid set to False
# 119 166
# Trials:  119  Journeys: 166
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-08052021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-08052021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-08052021-0107/ses.pickle
# 23 mn1173-09052021-0108 mn1173-09052021-0108
# mn1173-09052021-0108 trial segmentation
# Number of trials : 142
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-09052021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.25
# no bridge time before start; no adjustTrialStart
# mn1173-09052021-0108_1, add a journey missed because of no brige time before first arenaCenter
# mn1173-09052021-0108_6, position of the animal at first lever press unknown
# mn1173-09052021-0108_6, self.valid set to False
# mn1173-09052021-0108_7, position of the animal at first lever press unknown
# mn1173-09052021-0108_7, self.valid set to False
# mn1173-09052021-0108_8, position of the animal at first lever press unknown
# mn1173-09052021-0108_8, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-09052021-0108_48, position of the animal at first lever press unknown
# mn1173-09052021-0108_48, self.valid set to False
# mn1173-09052021-0108_55, position of the animal at first lever press unknown
# mn1173-09052021-0108_55, self.valid set to False
# mn1173-09052021-0108_64, position of the animal at first lever press unknown
# mn1173-09052021-0108_64, self.valid set to False
# mn1173-09052021-0108_66, position of the animal at first lever press unknown
# mn1173-09052021-0108_66, self.valid set to False
# mn1173-09052021-0108_68, position of the animal at first lever press unknown
# mn1173-09052021-0108_68, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-09052021-0108_72, position of the animal at first lever press unknown
# mn1173-09052021-0108_72, self.valid set to False
# mn1173-09052021-0108_76, position of the animal at first lever press unknown
# mn1173-09052021-0108_76, self.valid set to False
# mn1173-09052021-0108_126, position of the animal at first lever press unknown
# mn1173-09052021-0108_126, self.valid set to False
# 142 192
# Trials:  142  Journeys: 192
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-09052021-0108/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-09052021-0108/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-09052021-0108/ses.pickle
# 24 mn1173-11052021-0108 mn1173-11052021-0108
# mn1173-11052021-0108 trial segmentation
# problem with the door alternation
# Problem with index 4895
# Removing the second of two door closings (index :4895)
# Number of trials : 113
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-11052021-0108/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn1173-11052021-0108_57, position of the animal at first lever press unknown
# mn1173-11052021-0108_57, self.valid set to False
# mn1173-11052021-0108_97, start time adjustment: -15.2468 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn1173-11052021-0108_97, add a journey missed because of no brige time before first arenaCenter
# 113 132
# Trials:  113  Journeys: 132
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-11052021-0108/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-11052021-0108/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn1173/mn1173-11052021-0108/ses.pickle
# 25 TYY9524-16082021-0106 TYY9524-16082021-0106
# TYY9524-16082021-0106 trial segmentation
# Number of trials : 122
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY9524/TYY9524-16082021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# TYY9524-16082021-0106_3, position of the animal at first lever press unknown
# TYY9524-16082021-0106_3, self.valid set to False
# TYY9524-16082021-0106_7, position of the animal at first lever press unknown
# TYY9524-16082021-0106_7, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 8, journeyNo: 5, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY9524-16082021-0106_9, start time adjustment: -5.0639 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY9524-16082021-0106_9, add a journey missed because of no brige time before first arenaCenter
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# ...
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 108 229
# Trials:  108  Journeys: 229
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-17092021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-17092021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-17092021-0106/ses.pickle
# 31 TYY5622-19092021-0106 TYY5622-19092021-0106
# TYY5622-19092021-0106 trial segmentation
# problem with the door alternation
# Problem with index 2918
# Removing the second of two door closings (index :2918)
# Number of trials : 102
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-19092021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# TYY5622-19092021-0106_1, start time adjustment: -2666.8835 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY5622-19092021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 4, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY5622-19092021-0106_30, position of the animal at first lever press unknown
# TYY5622-19092021-0106_30, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 45, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 90, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 102 252
# Trials:  102  Journeys: 252
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-19092021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-19092021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-19092021-0106/ses.pickle
# 32 TYY5622-20092021-0106 TYY5622-20092021-0106
# TYY5622-20092021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 128
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-20092021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 6.75
# TYY5622-20092021-0106_1, start time adjustment: -2890.2968 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# TYY5622-20092021-0106_1, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 1, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# TYY5622-20092021-0106_90, position of the animal at first lever press unknown
# TYY5622-20092021-0106_90, self.valid set to False
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 103, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 119, journeyNo: 6, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 128 238
# Trials:  128  Journeys: 238
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-20092021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-20092021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/TYY5622/TYY5622-20092021-0106/ses.pickle
# 33 mn9686-20102021-0106 mn9686-20102021-0106
# mn9686-20102021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3225
# Removing the second of two door closings (index :3225)
# Number of trials : 147
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-20102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.25
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 2, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 3, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_10, position of the animal at first lever press unknown
# mn9686-20102021-0106_10, self.valid set to False
# We have a navPath with empty pPose in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_48, position of the animal at first lever press unknown
# mn9686-20102021-0106_48, self.valid set to False
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 60, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# trialNo: 60, journeyNo: 6, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 60, journeyNo: 7, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_91, position of the animal at first lever press unknown
# mn9686-20102021-0106_91, self.valid set to False
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-20102021-0106_144, position of the animal at first lever press unknown
# mn9686-20102021-0106_144, self.valid set to False
# 147 258
# Trials:  147  Journeys: 258
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-20102021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-20102021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-20102021-0106/ses.pickle
# 34 mn9686-26102021-0106 mn9686-26102021-0106
# mn9686-26102021-0106 trial segmentation
# Number of trials : 125
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-26102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 7.75
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 14, journeyNo: 0, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-26102021-0106_73, start time adjustment: -40.0199 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-26102021-0106_73, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 74, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# mn9686-26102021-0106_82, start time adjustment: -9.0814 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-26102021-0106_82, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 107, journeyNo: 1, not time on the arena, we will only have a `all` navPath
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 125 255
# Trials:  125  Journeys: 255
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-26102021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-26102021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-26102021-0106/ses.pickle
# 35 mn9686-27102021-0106 mn9686-27102021-0106
# mn9686-27102021-0106 trial segmentation
# Remove last opening of the door
# Number of trials : 138
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-27102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 8.25
# mn9686-27102021-0106_1, start time adjustment: -2145.0546 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-27102021-0106_1, add a journey missed because of no brige time before first arenaCenter
# We have a navPath with empty pPose in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 84, journeyNo: 5, not time on the arena, we will only have a `all` navPath
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 84, journeyNo: 7, not time on the arena, we will only have a `all` navPath
# mn9686-27102021-0106_138, position of the animal at first lever press unknown
# mn9686-27102021-0106_138, self.valid set to False
# 138 252
# Trials:  138  Journeys: 252
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-27102021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-27102021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-27102021-0106/ses.pickle
# 36 mn9686-28102021-0107 mn9686-28102021-0107
# mn9686-28102021-0107 trial segmentation
# Number of trials : 146
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-28102021-0107/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# mn9686-28102021-0107_1, start time adjustment: -2372.0206 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-28102021-0107_1, add a journey missed because of no brige time before first arenaCenter
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# mn9686-28102021-0107_146, no lever press or no mouse position
# mn9686-28102021-0107_146, self.valid set to False
# 146 224
# Trials:  146  Journeys: 224
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-28102021-0107/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-28102021-0107/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-28102021-0107/ses.pickle
# 37 mn9686-29102021-0106 mn9686-29102021-0106
# mn9686-29102021-0106 trial segmentation
# problem with the door alternation
# Problem with index 2776
# Removing the second of two door closings (index :2776)
# Number of trials : 138
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-29102021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 9.75
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 138 211
# Trials:  138  Journeys: 211
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-29102021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-29102021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-29102021-0106/ses.pickle
# 38 mn9686-01112021-0106 mn9686-01112021-0106
# mn9686-01112021-0106 trial segmentation
# problem with the door alternation
# Problem with index 3167
# Removing the second of two door closings (index :3167)
# Number of trials : 160
# leverZoneMaxDistance calculation
# reading /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-01112021-0106/leverZoneMaxDistance
# leverZoneMaxDistance: 10.0
# mn9686-01112021-0106_61, start time adjustment: -6.5549 sec
# {}, start time adjustment would be too large, something is wrong.
# keep original start time
# mn9686-01112021-0106_61, add a journey missed because of no brige time before first arenaCenter
# No time on the arena, can't cut at last arena bridge transition
# trialNo: 61, journeyNo: 3, not time on the arena, we will only have a `all` navPath
# mousePose.shape[0] for a navPath in 0 in journeyElectro.createNavPath
# We have a None navPath in our dictionary, only keeping the all path
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# Could not find a homingPath in j.navPaths.keys()
# Could not find a searchToLeverPath in j.navPaths.keys()
# 160 261
# Trials:  160  Journeys: 261
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-01112021-0106/navPathSummary.csv
# saving /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-01112021-0106/navPathInstan.csv
# Saving: /ext_drives/d80/Jazi_etal_2023/autopi_ca1/mn9686/mn9686-01112021-0106/ses.pickle

# %% [markdown]
# Function to plot a single trial

# %%
trial = ses.trialList[17]
fig, axes = plt.subplots(1,6,figsize=(4*6,5))
trial.plotTrialAndJourneys(axes,legendSize=8)

# %%
fn = ses.path+"/navPathSummary.csv"
pd.read_csv(fn)
# Out:
#                                                    name  \
# 0                          mn9686-01112021-0106_1-0_all
# 1                   mn9686-01112021-0106_1-0_searchPath
# 2            mn9686-01112021-0106_1-0_searchToLeverPath
# 3                   mn9686-01112021-0106_1-0_homingPath
# 4       mn9686-01112021-0106_1-0_homingFromLeavingLever
# ...                                                 ...
# 1210       mn9686-01112021-0106_160-1_searchToLeverPath
# 1211              mn9686-01112021-0106_160-1_homingPath
# 1212  mn9686-01112021-0106_160-1_homingFromLeavingLever
# 1213  mn9686-01112021-0106_160-1_homingFromLeavingLe...
# 1214                 mn9686-01112021-0106_160-1_atLever
#
#                          trial  trialNo  journey  \
# 0       mn9686-01112021-0106_1        1        0
# 1       mn9686-01112021-0106_1        1        0
# 2       mn9686-01112021-0106_1        1        0
# 3       mn9686-01112021-0106_1        1        0
# 4       mn9686-01112021-0106_1        1        0
# ...                        ...      ...      ...
# 1210  mn9686-01112021-0106_160      160        1
# 1211  mn9686-01112021-0106_160      160        1
# 1212  mn9686-01112021-0106_160      160        1
# 1213  mn9686-01112021-0106_160      160        1
# 1214  mn9686-01112021-0106_160      160        1
#
#                                    type  light  nLeverPresses  startTimeRos  \
# 0                                   all  light              1  1.635781e+09
# 1                            searchPath  light              1  1.635781e+09
# 2                     searchToLeverPath  light              1  1.635781e+09
# 3                            homingPath  light              1  1.635781e+09
# 4                homingFromLeavingLever  light              1  1.635781e+09
# ...                                 ...    ...            ...           ...
# 1210                  searchToLeverPath   dark              1  1.635786e+09
# 1211                         homingPath   dark              1  1.635786e+09
# 1212             homingFromLeavingLever   dark              1  1.635786e+09
# 1213  homingFromLeavingLeverToPeriphery   dark              1  1.635786e+09
# 1214                            atLever   dark              1  1.635786e+09
#
#         endTimeRos  startTimeRes  endTimeRes
# 0     1.635781e+09       3057.72     3066.90
# 1     1.635781e+09       3057.72     3065.70
# 2     1.635781e+09       3057.72     3065.04
# 3     1.635781e+09       3065.72     3066.90
# 4     1.635781e+09       3066.16     3066.90
# ...            ...           ...         ...
# 1210  1.635786e+09       8390.98     8391.16
# 1211  1.635786e+09       8391.78     8393.80
# 1212  1.635786e+09       8393.10     8393.80
# 1213  1.635786e+09       8393.10     8393.22
# 1214  1.635786e+09       8391.16     8393.10
#
# [1215 rows x 11 columns]

# %%
navPathInstan = ses.navPathInstantaneousBehavioralData()
navPathInstan
# Out:
#                                   name  trialNo       timeRos  timeRes  \
# 0         mn9686-01112021-0106_1-0_all        1  1.635781e+09  3057.72
# 1         mn9686-01112021-0106_1-0_all        1  1.635781e+09  3057.74
# 2         mn9686-01112021-0106_1-0_all        1  1.635781e+09  3057.76
# 3         mn9686-01112021-0106_1-0_all        1  1.635781e+09  3057.78
# 4         mn9686-01112021-0106_1-0_all        1  1.635781e+09  3057.80
# ..                                 ...      ...           ...      ...
# 93  mn9686-01112021-0106_160-1_atLever      160  1.635786e+09  8393.02
# 94  mn9686-01112021-0106_160-1_atLever      160  1.635786e+09  8393.04
# 95  mn9686-01112021-0106_160-1_atLever      160  1.635786e+09  8393.06
# 96  mn9686-01112021-0106_160-1_atLever      160  1.635786e+09  8393.08
# 97  mn9686-01112021-0106_160-1_atLever      160  1.635786e+09  8393.10
#
#        iTime  iTimeProp   distance  distanceProp      speed          x  \
# 0   0.000000   0.000000   0.226477      0.000939  10.469781  -1.547535
# 1   0.021631   0.002355   0.521394      0.002163  11.984293  -1.505792
# 2   0.046240   0.005035   0.817749      0.003392  13.761295  -1.477743
# 3   0.067775   0.007380   1.209617      0.005018  20.032589  -1.470911
# 4   0.087337   0.009510   1.694762      0.007030  30.082162  -1.502748
# ..       ...        ...        ...           ...        ...        ...
# 93  1.858261   0.950462  64.690139      0.965279  35.879708 -18.847819
# 94  1.879748   0.961452  65.473458      0.976967  36.726040 -18.781886
# 95  1.901077   0.972361  66.251160      0.988572  36.775143 -18.668076
# 96  1.922224   0.983178  67.017058      1.000000  23.287125 -18.505967
# 97  1.955114   1.000000  67.017058      1.000000        NaN -18.327809
#
#             y  targetDistance  targetToAnimalX  targetToAnimalY  \
# 0  -42.772820       43.748974        -0.886454       -49.407187
# 1  -42.550224       43.525129        -0.844711       -49.184590
# 2  -42.256644       43.230798        -0.816662       -48.891010
# 3  -41.960367       42.934455        -0.809830       -48.594734
# 4  -41.569795       42.545125        -0.841667       -48.204161
# ..        ...             ...              ...              ...
# 93 -25.363831        8.941222       -15.222911        -1.085322
# 94 -26.131971        9.217626       -15.156978        -1.853462
# 95 -26.906977        9.511755       -15.043168        -2.628468
# 96 -27.667596        9.812199       -14.881058        -3.389087
# 97 -28.412486       10.123331       -14.702900        -4.133976
#
#     targetToAnimalAngle  cumSumDiffAngleAroundTarget
# 0             -1.588736                          NaN
# 1             -1.587969                     0.000767
# 2             -1.587499                     0.001238
# 3             -1.587460                     0.001276
# 4             -1.588255                     0.000481
# ..                  ...                          ...
# 93            -3.070418                     4.739598
# 94            -3.019912                     4.790103
# 95            -2.968611                     4.841405
# 96            -2.917667                     4.892349
# 97            -2.867502                     4.942514
#
# [172882 rows x 16 columns]
